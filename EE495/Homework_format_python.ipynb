# %% [markdown]
# # EE444/588 Project Format
# Student name

# %% [markdown]
# ## A Note on Jupyter Notebooks
#
# There are two main types of cells in this notebook: code and markdown (text).  You can add a new cell with the plus sign in the menu bar above and you can change the type of cell with the dropdown menu in the menu bar above.
#
# Markdown cells can be augmented with a number of text formatting features, including
#   - bulleted
#   - lists
#
# embedded $\LaTeX$, monotype specification of `code syntax`, **bold font**, and *italic font*.  There are many other features of markdown cells--see the jupyter documentation for more information.
#
# You can edit a cell by double clicking on it.  If you double click on this cell, you can see how to implement the various formatting referenced above.  Code cells can be run and markdown cells can be formatted using Shift+Enter or by selecting the Run button in the toolbar above.
#
# Once you have completed (all or part) of this notebook, you can share your results with colleagues by sending them the `.ipynb` file.  Your colleagues can then open the file and will see your markdown and code cells as well as any results that were printed or displayed at the time you saved the notebook.  If you prefer to send a notebook without results displayed, you can select ("Restart & Clear Output") from the Kernel menu above.  You can also export this notebook in a non-executable form, e.g., `.pdf` through the File, Download As menu.

# %% [markdown]
# Put all the import stuff here

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
# the next line includes plots inline instead of in a separate figure window
# %matplotlib inline 
# The next line changes the fontsize on the plots.  For some reason, you may need to run this cell, then plot
# something, then run this cell again, and then plot something again in order for the settings to take.
plt.rcParams.update({'font.size': 20})

# %% [markdown]
# ## (a)
# Here's where a brief introduction goes.  The next cell will be code. When you run that code, the output, whether it be figure windows or printouts will display below the code.

# %%
x = np.arange(1,10)

plt.figure(figsize=(10,10)) # The figsize adjusts the size of the window.  Change it to suit your system
plt.plot(x)
plt.xlabel('x')
plt.ylabel('x also')
plt.title('This is x')
plt.show() # This suppresses printing of the figure handle (or something equally not useful to see)

print('This is x:')
print(x)
# Out:
# This is x:
# [1 2 3 4 5 6 7 8 9]

# %% [markdown]
# Above you can see the output displayed as both a plot and printed out.
